# %% [markdown]
# # FDW Crop Production Data Profiling - Sudan and South Sudan

# %%
import os, sys, glob, json
from itertools import product, compress, chain
from functools import reduce
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import requests
import numpy as np
import pandas as pd
import geopandas as gpd
from tools import save_hdf, save_npz, load_npz, PrintAdminUnits, PlotAdminShapes
from tools import FDW_PD_Sweeper, FDW_PD_AvalTable, FDW_PD_Compiling, FDW_PD_GrainTypeAgg, FDW_PD_ValidateFnidName
from tools import FDW_PD_CreateAdminLink, FDW_PD_RatioAdminLink, FDW_PD_ConnectAdminLink
from tools import product_name_mapping, FDW_PD_CaliSeasonYear
from tools_graphic import PlotBarProduction, PlotLinePAY
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

# %%
# CPCV2 grain code ------------------------------ #
grain_code = pd.read_hdf('../data/crop/grain_cpcv2_code.hdf')
product_category = grain_code[['product', 'product_category']].set_index('product').to_dict()['product_category']
# ----------------------------------------------- #

# Load FEWS NET administrative boundaries ------- #
epsg = 'EPSG:20135'
fn_shapes = sorted(glob.glob('../data/shapefile/fewsnet/SD_Admin?_????.shp'))+\
            sorted(glob.glob('../data/shapefile/fewsnet/SS_Admin?_????.shp')) # search for both Sudan and South Sudan boundaries
shape_all = []
for fn in fn_shapes:
    name = fn[-18:-4]
    exec('%s = gpd.read_file("%s").to_crs("%s")' % (name, fn, epsg))
    exec('%s["area"] = %s["geometry"].area/10**6' % (name, name))
    exec('shape_all.append(%s)' % (name))
shape_all = pd.concat(shape_all, axis=0).reset_index(drop=True)
PrintAdminUnits(shape_all)
# ----------------------------------------------- #

# FDW API host address -------------------------- #
host = 'https://fdw.fews.net'
#read in username and password
# auth = tuple(json.loads(open('token.json', "r").read()))
parameters = {
    'format': 'json',
    'country': ['Sudan','South Sudan'],
    'product': ['R011','R012','R013','R014','R015','R016','R017','R018','R019'],
    'survey_type': 'crop:best'
}
endpoint = '/api/cropproductionindicatorvalue/'
response = requests.get(host + endpoint, params=parameters,  proxies={})
response.raise_for_status()
df = pd.DataFrame.from_records(response.json())
df_origin = df.copy()
# ----------------------------------------------- #
# Out:
# - FEWS NET admin shapefiles ------------------- #
# | year	 | Admin1   | # units   | Admin2   | # units   | Admin3   | # units   |
# | 1976	 | SD1976A1 | 18	| nan	| 0	| nan	| 0	|
# | 1990	 | SD1990A1 | 26	| nan	| 0	| nan	| 0	|
# | 2005	 | SD2005A1 | 25	| nan	| 0	| nan	| 0	|
# | 2011	 | SD2011A1 | 15	| SD2011A2	| 133	| nan	| 0	|
# | 2011	 | SD2011A1 | 15	| SS2011A2	| 79	| nan	| 0	|
# | 2011	 | SS2011A1 | 10	| SD2011A2	| 133	| nan	| 0	|
# | 2011	 | SS2011A1 | 10	| SS2011A2	| 79	| nan	| 0	|
# | 2012	 | SD2012A1 | 17	| nan	| 0	| nan	| 0	|
# | 2013	 | SD2013A1 | 18	| nan	| 0	| nan	| 0	|
# | 2014	 | SD2014A1 | 18	| SD2014A2	| 172	| nan	| 0	|
# ----------------------------------------------- #

# %%
# Save data
df_raw_out = '../data/crop_raw_data/adm_crop_data_raw_SDSS.csv'
df.to_csv(df_raw_out); print(f'{df_raw_out} is saved.')
# Out:
# ../data/crop_raw_data/adm_crop_data_raw_SDSS.csv is saved.

# %%
# In this cell we pull in the South Sudan shapefile to create continuous timeseries in the pre- and post- South Sudan period
#Merge South Sudan admins into the post-2011 Sudan admin files
SD_Admin1_2011 = SS_Admin1_2011.merge(SD_Admin1_2011,'outer')
SD_Admin1_2012 = SS_Admin1_2011.merge(SD_Admin1_2012,'outer') #South sudan has no new boundaries after 2011, so keep adding 2011
SD_Admin1_2013 = SS_Admin1_2011.merge(SD_Admin1_2013,'outer') 
SD_Admin1_2014 = SS_Admin1_2011.merge(SD_Admin1_2014,'outer')

#Matching happens on country later so we need to specify that we're creating time series that began with Sudan as the country
SD_Admin1_2011['COUNTRY'] = 'SD'; SD_Admin1_2011['ADMIN0'] = 'Sudan'
SD_Admin1_2012['COUNTRY'] = 'SD'; SD_Admin1_2012['ADMIN0'] = 'Sudan'
SD_Admin1_2013['COUNTRY'] = 'SD'; SD_Admin1_2013['ADMIN0'] = 'Sudan'
SD_Admin1_2014['COUNTRY'] = 'SD'; SD_Admin1_2014['ADMIN0'] = 'Sudan'

# Change the season name from "Main harvest" to "Main"
df['season_name'] = df['season_name'].replace('Main harvest', 'Main')

# %%
# Manual Pre-processing before Sweeping --------- #
# 1. Default setting 
# a) None-type crop production system
df.loc[df['crop_production_system'].isna(), 'crop_production_system'] = 'none'
df.loc[df['crop_production_system'] == '', 'crop_production_system'] = 'none'
# b) None-type population group
df.loc[df['population_group'].isna(), 'population_group'] = 'none'
df.loc[df['population_group'] == '', 'population_group'] = 'none'

# Drop items at the country level (w/ FNID = 'SD')
df = df.loc[~(df.fnid=='SD')]

# Drop the IOM population group in South Sudan
df = df.loc[~(df['population_group'] ==  'Returnees (by IOM)')]

#Drop the blank (nan) rows that are duplicates of rows that do have data
df = df[np.isfinite(df.value)]

#drop the admin 0 observations
df = df[~(df.fnid.astype(str).str[6:8]=='A0')]

#drop the admin 2 observations (by selecting for None type) because in there aren't enough to make a dataset from
df = df[df['admin_2'].isna()]

# FDW Production Data Inspection ---------------- #
df, df_raw = FDW_PD_Sweeper(df)
table_dict = FDW_PD_AvalTable(df, shape_all)
# ----------------------------------------------- #

# FEWS NET Shapefile comparison ----------------- #
shape_used = pd.concat([SD_Admin1_1976,SD_Admin1_1990,SD_Admin1_2005,SD_Admin1_2011,SS_Admin1_2011,SD_Admin1_2012,SD_Admin1_2013], axis=0)
PlotAdminShapes(shape_used, label=True)
# ----------------------------------------------- #
# Out:
# - Remove missing records ---------------------- #
# Orignial data points: 14,933
# 3,850/3,850 "Area Harvested" points are retained.
# 3,851/3,851 "Quantity Produced" points are retained.
# 3,851/3,851 "Yield" points are retained.
# 3,381/3,381 "Area Planted" points are retained.
# Current data points: 14,933
#
# - Minor changes are applied ------------------- #
#
# - Basic information --------------------------- #
# Data period: 1975 - 2023
# 14 grain types are found: Cereal Crops (Mixed), Cotton (Acala), Cotton (American), Cotton (Egyptian), Cotton (Unspecified), Groundnuts (In Shell), Millet, Pigeon Peas, Pigeon pea (Unspecified), Sesame Seed, Sorghum, Sugarcane (for sugar), Sunflower Seed, Wheat Grain
# 2 seasons are found: Main (10-01), Annual (06-01), Main (06-01)
# 8 crop production system are found: none, All (PS), irrigated, Mechanized (PS), traditional_rainfed, Rainfed (PS), Semi-Mechanized (PS), mechanized_rainfed
# Data sources include:
# [1] FAO, WFP, Government of South Sudan (GoSS)  --- CFSAM special report, South Sudan
# [2] FAO CFSAM, Sudan --- CFSAM agricultural statistics, Sudan, crop
# [3] Federal Ministry of Agriculture and Forestry (FMoA&F), Sudan --- Official agricultural statistics, Sudan
# Administrative-1 fnids: 102
# Administrative-2 fnids: 29
# 30 reporting units are found: SD2005R20905, SD2005R20910, SD2005R20911, SD2005R21002, SD2005R21101, SD2005R21103, SD2005R21108, SD2005R21201, SD2005R21901, SD1990R101, SD1990R20908, SD1990R20911, SD1990R21002, SD1990R21103, SD1990R21104, SD1990R21105, SD1990R21107, SD1990R21201, SD1990R21501, SD1990R21502, SD1990R21503, SD1990R22901, SD2005R20101, SD2005R20908, SD2005R21104, SD2005R21105, SD2005R21107, SD2005R21501, SD2005R21502, SD2005R21503
#
# - Total production over time ------------------ #
# season_name              Annual   Main
#
# Cereal Crops (Mixed)       0.0%   0.5%
# Cotton (Acala)             0.6%   0.0%
# Cotton (American)          0.0%   0.0%
# Cotton (Egyptian)          0.3%   0.0%
# Cotton (Unspecified)       0.5%   0.7%
# Groundnuts (In Shell)      0.0%  12.8%
# Millet                     0.0%   9.8%
# Pigeon Peas                0.0%   0.0%
# Pigeon pea (Unspecified)   0.0%   0.1%
# Sesame Seed                0.0%   4.7%
# Sorghum                    8.8%  41.3%
# Sugarcane (for sugar)     14.6%   0.0%
# Sunflower Seed             0.0%   0.6%
# Wheat Grain                4.3%   0.4%
#
# - Crop calendar ------------------------------- #
#                      product season_name planting_month harvest_month
# 0       Cereal Crops (Mixed)        Main          10-01         01-01
# 1             Cotton (Acala)      Annual          06-01         05-01
# 2          Cotton (American)        Main          06-01         10-01
# 3          Cotton (Egyptian)      Annual          06-01         05-01
# 4       Cotton (Unspecified)      Annual          06-01         05-01
# 5       Cotton (Unspecified)        Main          06-01         10-01
# 6      Groundnuts (In Shell)        Main          06-01         10-01
# 7                     Millet        Main          06-01         10-01
# 8                Pigeon Peas        Main          06-01         10-01
# 9   Pigeon pea (Unspecified)        Main          06-01         10-01
# 10               Sesame Seed        Main          06-01         10-01
# 11                   Sorghum        Main          06-01         10-01
# 12                   Sorghum      Annual          06-01         05-01
# 13     Sugarcane (for sugar)      Annual          06-01         05-01
# 14            Sunflower Seed        Main          06-01         10-01
# 15               Wheat Grain      Annual          06-01         05-01
# 16               Wheat Grain        Main          06-01         10-01
#
# - Recorded years per season ------------------- #
# Main: 49 years (1975-2023) (missing: 0 years)
# Annual: 49 years (1975-2023) (missing: 1 years)
#
# - Number of "Quantity Produced" data points --- #
# SD1976A1: 285 data points are found.
# SD1990A1: 1,130 data points are found.
# SD1990R1: 51 data points are found.
# SD1990R2: 277 data points are found.
# SD2005A1: 480 data points are found.
# SD2005R2: 367 data points are found.
# SD2011A1: 73 data points are found.
# SD2012A1: 81 data points are found.
# SD2013A1: 1,087 data points are found.
# SS2011A1: 20 data points are found.
#
# - Districts with population group(s) ---------- #
# 0 districts includes 'population_group'.
#
# Table of available data
# ----------------------------------------------- #
# Crop type: Cereal Crops (Mixed)
# ----------------------------------------------- #
# season_name              Main
# crop_production_system   none
# fnid_short             2011A1
# year
# 2011                    10/25
# 2012                    10/25
# ----------------------------------------------- #
# Crop type: Cotton (Acala)
# ----------------------------------------------- #
# season_name               Annual
# crop_production_system irrigated
# fnid_short                1990A1 1990R2 2005A1 2005R2 2011A1 2012A1 2013A1
# year
# 1990                         NaN      3    NaN    NaN    NaN    NaN    NaN
# 1991                         NaN      3    NaN    NaN    NaN    NaN    NaN
# 1992                         NaN      3    NaN    NaN    NaN    NaN    NaN
# 1993                         NaN      3    NaN    NaN    NaN    NaN    NaN
# 1994                        1/26      4    NaN    NaN    NaN    NaN    NaN
# 1995                        1/26      4    NaN    NaN    NaN    NaN    NaN
# 1996                        2/26      4    NaN    NaN    NaN    NaN    NaN
# 1997                        1/26      3    NaN    NaN    NaN    NaN    NaN
# 1998                        1/26      4    NaN    NaN    NaN    NaN    NaN
# 1999                        1/26      4    NaN    NaN    NaN    NaN    NaN
# 2000                        2/26      4    NaN    NaN    NaN    NaN    NaN
# 2001                        2/26      4    NaN    NaN    NaN    NaN    NaN
# 2002                        2/26      4    NaN    NaN    NaN    NaN    NaN
# 2003                        1/26      3    NaN    NaN    NaN    NaN    NaN
# 2004                        2/26      3    NaN    NaN    NaN    NaN    NaN
# 2005                         NaN    NaN   2/25      4    NaN    NaN    NaN
# 2006                         NaN    NaN   2/25      5    NaN    NaN    NaN
# 2007                         NaN    NaN   2/25      5    NaN    NaN    NaN
# 2008                         NaN    NaN   2/25      5    NaN    NaN    NaN
# 2009                         NaN    NaN   2/25      3    NaN    NaN    NaN
# 2010                         NaN    NaN    NaN      3    NaN    NaN    NaN
# 2011                         NaN    NaN    NaN      5   1/25    NaN    NaN
# 2012                         NaN    NaN    NaN      4    NaN   1/17    NaN
# 2013                         NaN    NaN    NaN      5    NaN    NaN   1/18
# 2014                         NaN    NaN    NaN      4    NaN    NaN    NaN
# 2015                         NaN    NaN    NaN    NaN    NaN    NaN   5/18
# ----------------------------------------------- #
# Crop type: Cotton (American)
# ----------------------------------------------- #
# season_name                           Main
# crop_production_system traditional_rainfed
# fnid_short                          1990A1 1990R1 2005A1 2011A1 2012A1 2013A1
# year
# 1990                                  1/26    NaN    NaN    NaN    NaN    NaN
# 1991                                  3/26    NaN    NaN    NaN    NaN    NaN
# 1992                                  3/26    NaN    NaN    NaN    NaN    NaN
# 1993                                  3/26    NaN    NaN    NaN    NaN    NaN
# 1994                                  4/26    NaN    NaN    NaN    NaN    NaN
# 1995                                  5/26    NaN    NaN    NaN    NaN    NaN
# 1996                                  6/26      1    NaN    NaN    NaN    NaN
# 1997                                  4/26    NaN    NaN    NaN    NaN    NaN
# 1998                                  4/26    NaN    NaN    NaN    NaN    NaN
# 1999                                  4/26    NaN    NaN    NaN    NaN    NaN
# 2000                                  2/26    NaN    NaN    NaN    NaN    NaN
# 2001                                  3/26    NaN    NaN    NaN    NaN    NaN
# 2002                                  4/26    NaN    NaN    NaN    NaN    NaN
# 2003                                  3/26      1    NaN    NaN    NaN    NaN
# 2004                                  3/26    NaN    NaN    NaN    NaN    NaN
# 2005                                   NaN    NaN   5/25    NaN    NaN    NaN
# 2006                                   NaN    NaN   4/25    NaN    NaN    NaN
# 2007                                   NaN    NaN   4/25    NaN    NaN    NaN
# 2008                                   NaN    NaN   4/25    NaN    NaN    NaN
# 2009                                   NaN    NaN   2/25    NaN    NaN    NaN
# 2010                                   NaN    NaN   2/25    NaN    NaN    NaN
# 2011                                   NaN    NaN    NaN   2/25    NaN    NaN
# 2012                                   NaN    NaN    NaN    NaN   2/17    NaN
# 2013                                   NaN    NaN    NaN    NaN    NaN   2/18
# 2014                                   NaN    NaN    NaN    NaN    NaN   2/18
# 2015                                   NaN    NaN    NaN    NaN    NaN   2/18
# ----------------------------------------------- #
# Crop type: Cotton (Egyptian)
# ----------------------------------------------- #
# season_name               Annual
# crop_production_system irrigated
# fnid_short                1990A1 1990R2 2005R2 2013A1
# year
# 1990                        1/26      2    NaN    NaN
# 1991                         NaN      3    NaN    NaN
# 1992                         NaN      3    NaN    NaN
# 1993                         NaN      3    NaN    NaN
# 1994                        1/26      3    NaN    NaN
# 1995                        1/26      3    NaN    NaN
# 1996                        1/26      3    NaN    NaN
# 1997                         NaN      2    NaN    NaN
# 1998                         NaN      2    NaN    NaN
# 1999                         NaN      2    NaN    NaN
# 2000                         NaN      2    NaN    NaN
# 2001                         NaN      2    NaN    NaN
# 2002                         NaN      3    NaN    NaN
# 2003                         NaN      4    NaN    NaN
# 2004                         NaN      3    NaN    NaN
# 2005                         NaN    NaN      2    NaN
# 2006                         NaN    NaN      2    NaN
# 2007                         NaN    NaN      2    NaN
# 2008                         NaN    NaN      2    NaN
# 2009                         NaN    NaN      1    NaN
# 2010                         NaN    NaN      1    NaN
# 2011                         NaN    NaN      1    NaN
# 2012                         NaN    NaN      1    NaN
# 2013                         NaN    NaN      1    NaN
# 2014                         NaN    NaN      1    NaN
# 2015                         NaN    NaN    NaN   1/18
# ----------------------------------------------- #
# Crop type: Cotton (Unspecified)
# ----------------------------------------------- #
# season_name               Annual                Main
# crop_production_system irrigated        Rainfed (PS) irrigated        traditional_rainfed
# fnid_short                2005R2 2013A1       2013A1    2005R2 2013A1              2013A1
# year
# 2016                           4   3/18          NaN       NaN    NaN                1/18
# 2017                           4   4/18         3/18       NaN    NaN                3/18
# 2018                           3   4/18         1/18       NaN    NaN                 NaN
# 2019                           5   4/18         3/18       NaN    NaN                 NaN
# 2020                         NaN    NaN          NaN       NaN    NaN                3/18
# 2021                         NaN    NaN         3/18         3   2/18                4/18
# 2022                           3   3/18         4/18       NaN    NaN                 NaN
# ----------------------------------------------- #
# Crop type: Groundnuts (In Shell)
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS) irrigated                                           mechanized_rainfed traditional_rainfed
# fnid_short                   2013A1    1990A1 1990R2 2005A1 2005R2 2011A1 2012A1 2013A1             2013A1              1990A1 2005A1 2011A1 2012A1 2013A1
# year
# 1990                            NaN      1/26      3    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 1991                            NaN      1/26      2    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 1992                            NaN      1/26      3    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 1993                            NaN      1/26      3    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 1994                            NaN      1/26      3    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 1995                            NaN      1/26      3    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 1996                            NaN      1/26      3    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 1997                            NaN      1/26      2    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 1998                            NaN      1/26      2    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 1999                            NaN      1/26      2    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 2000                            NaN      1/26      2    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 2001                            NaN      1/26      2    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 2002                            NaN      1/26      2    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 2003                            NaN      1/26      2    NaN    NaN    NaN    NaN    NaN                NaN                7/26    NaN    NaN    NaN    NaN
# 2004                            NaN      1/26      2    NaN    NaN    NaN    NaN    NaN                NaN                8/26    NaN    NaN    NaN    NaN
# 2005                            NaN       NaN    NaN   1/25      2    NaN    NaN    NaN                NaN                 NaN   7/25    NaN    NaN    NaN
# 2006                            NaN       NaN    NaN   1/25      3    NaN    NaN    NaN                NaN                 NaN   8/25    NaN    NaN    NaN
# 2007                            NaN       NaN    NaN   1/25      3    NaN    NaN    NaN                NaN                 NaN   8/25    NaN    NaN    NaN
# 2008                            NaN       NaN    NaN   1/25      3    NaN    NaN    NaN                NaN                 NaN   8/25    NaN    NaN    NaN
# 2009                            NaN       NaN    NaN   1/25      2    NaN    NaN    NaN                NaN                 NaN   8/25    NaN    NaN    NaN
# 2010                            NaN       NaN    NaN   1/25      3    NaN    NaN    NaN                NaN                 NaN   7/25    NaN    NaN    NaN
# 2011                            NaN       NaN    NaN    NaN      3   1/25    NaN    NaN                NaN                 NaN    NaN   7/25    NaN    NaN
# 2012                            NaN       NaN    NaN    NaN      3    NaN   1/17    NaN                NaN                 NaN    NaN    NaN   9/17    NaN
# 2013                            NaN       NaN    NaN    NaN      3    NaN    NaN   1/18                NaN                 NaN    NaN    NaN    NaN  10/18
# 2014                            NaN       NaN    NaN    NaN      3    NaN    NaN   1/18                NaN                 NaN    NaN    NaN    NaN  10/18
# 2015                            NaN       NaN    NaN    NaN    NaN    NaN    NaN   4/18               1/18                 NaN    NaN    NaN    NaN  10/18
# 2016                          10/18       NaN    NaN    NaN      2    NaN    NaN   4/18               5/18                 NaN    NaN    NaN    NaN   6/18
# 2017                          11/18       NaN    NaN    NaN      2    NaN    NaN   1/18                NaN                 NaN    NaN    NaN    NaN    NaN
# 2018                          11/18       NaN    NaN    NaN      2    NaN    NaN   1/18                NaN                 NaN    NaN    NaN    NaN    NaN
# 2019                          10/18       NaN    NaN    NaN      2    NaN    NaN   1/18                NaN                 NaN    NaN    NaN    NaN    NaN
# 2020                            NaN       NaN    NaN    NaN      1    NaN    NaN    NaN                NaN                 NaN    NaN    NaN    NaN  10/18
# 2021                            NaN       NaN    NaN    NaN      2    NaN    NaN  11/18                NaN                 NaN    NaN    NaN    NaN  10/18
# 2022                          11/18       NaN    NaN    NaN      2    NaN    NaN   1/18                NaN                 NaN    NaN    NaN    NaN    NaN
# ----------------------------------------------- #
# Crop type: Millet
# ----------------------------------------------- #
# season_name                       Main
# crop_production_system Mechanized (PS) Semi-Mechanized (PS) irrigated                                    mechanized_rainfed                             traditional_rainfed
# fnid_short                      2005R2               2013A1    1990A1 2005A1 2005R2 2011A1 2012A1 2013A1             1990A1 2005A1 2011A1 2012A1 2013A1              1976A1 1990A1 1990R1 1990R2 2005A1 2005R2 2011A1 2012A1 2013A1
# year
# 1975                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                6/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1976                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                6/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1977                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                6/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1978                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                6/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1979                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                6/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1980                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                6/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1981                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                6/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1982                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                6/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1983                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                6/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1984                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                6/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1985                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                6/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1986                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                4/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1987                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                4/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1988                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                4/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1989                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                4/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1990                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN    NaN               5/26    NaN    NaN    NaN    NaN                 NaN   9/26    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1991                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               5/26    NaN    NaN    NaN    NaN                 NaN   9/26    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1992                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               5/26    NaN    NaN    NaN    NaN                 NaN   9/26    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1993                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               6/26    NaN    NaN    NaN    NaN                 NaN  10/26      1    NaN    NaN    NaN    NaN    NaN    NaN
# 1994                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               7/26    NaN    NaN    NaN    NaN                 NaN   9/26      1    NaN    NaN    NaN    NaN    NaN    NaN
# 1995                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               6/26    NaN    NaN    NaN    NaN                 NaN   9/26      1    NaN    NaN    NaN    NaN    NaN    NaN
# 1996                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               6/26    NaN    NaN    NaN    NaN                 NaN   9/26      1    NaN    NaN    NaN    NaN    NaN    NaN
# 1997                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               6/26    NaN    NaN    NaN    NaN                 NaN   9/26      1    NaN    NaN    NaN    NaN    NaN    NaN
# 1998                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               6/26    NaN    NaN    NaN    NaN                 NaN  10/26      1    NaN    NaN    NaN    NaN    NaN    NaN
# 1999                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               5/26    NaN    NaN    NaN    NaN                 NaN  10/26      1    NaN    NaN    NaN    NaN    NaN    NaN
# 2000                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               5/26    NaN    NaN    NaN    NaN                 NaN  10/26      1    NaN    NaN    NaN    NaN    NaN    NaN
# 2001                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               3/26    NaN    NaN    NaN    NaN                 NaN  10/26    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2002                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               4/26    NaN    NaN    NaN    NaN                 NaN  10/26    NaN      1    NaN    NaN    NaN    NaN    NaN
# 2003                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               4/26    NaN    NaN    NaN    NaN                 NaN  10/26      1      1    NaN    NaN    NaN    NaN    NaN
# 2004                               NaN                  NaN      1/26    NaN    NaN    NaN    NaN    NaN               4/26    NaN    NaN    NaN    NaN                 NaN  10/26    NaN      1    NaN    NaN    NaN    NaN    NaN
# 2005                               NaN                  NaN       NaN   1/25    NaN    NaN    NaN    NaN                NaN   6/25    NaN    NaN    NaN                 NaN    NaN    NaN    NaN   9/25      1    NaN    NaN    NaN
# 2006                               NaN                  NaN       NaN   1/25    NaN    NaN    NaN    NaN                NaN   6/25    NaN    NaN    NaN                 NaN    NaN      1    NaN   9/25      1    NaN    NaN    NaN
# 2007                               NaN                  NaN       NaN   1/25    NaN    NaN    NaN    NaN                NaN   6/25    NaN    NaN    NaN                 NaN    NaN      1    NaN   9/25      1    NaN    NaN    NaN
# 2008                               NaN                  NaN       NaN   1/25    NaN    NaN    NaN    NaN                NaN   6/25    NaN    NaN    NaN                 NaN    NaN      1    NaN   9/25      1    NaN    NaN    NaN
# 2009                               NaN                  NaN       NaN   1/25    NaN    NaN    NaN    NaN                NaN   6/25    NaN    NaN    NaN                 NaN    NaN      1    NaN  10/25      1    NaN    NaN    NaN
# 2010                               NaN                  NaN       NaN   1/25    NaN    NaN    NaN    NaN                NaN   5/25    NaN    NaN    NaN                 NaN    NaN    NaN    NaN  10/25      1    NaN    NaN    NaN
# 2011                               NaN                  NaN       NaN    NaN    NaN   1/25    NaN    NaN                NaN    NaN   5/25    NaN    NaN                 NaN    NaN    NaN    NaN    NaN      1  10/25    NaN    NaN
# 2012                               NaN                  NaN       NaN    NaN    NaN    NaN   1/17    NaN                NaN    NaN    NaN   5/17    NaN                 NaN    NaN    NaN    NaN    NaN      1    NaN  11/17    NaN
# 2013                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN   1/18                NaN    NaN    NaN    NaN   5/18                 NaN    NaN    NaN    NaN    NaN      1    NaN    NaN  13/18
# 2014                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN   1/18                NaN    NaN    NaN    NaN   5/18                 NaN    NaN    NaN    NaN    NaN      1    NaN    NaN  13/18
# 2015                               NaN                  NaN       NaN    NaN    NaN    NaN    NaN   1/18                NaN    NaN    NaN    NaN   5/18                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  12/18
# 2016                                 1                 5/18       NaN    NaN    NaN    NaN    NaN   1/18                NaN    NaN    NaN    NaN   6/18                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  12/18
# 2017                                 1                 5/18       NaN    NaN      1    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  12/18
# 2018                               NaN                 3/18       NaN    NaN      1    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  14/18
# 2019                               NaN                 5/18       NaN    NaN      1    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  14/18
# 2020                               NaN                 5/18       NaN    NaN      1    NaN    NaN    NaN                NaN    NaN    NaN    NaN   5/18                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  14/18
# 2021                               NaN                 5/18       NaN    NaN      1    NaN    NaN    NaN                NaN    NaN    NaN    NaN   5/18                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  14/18
# 2022                               NaN                 3/18       NaN    NaN      1    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  13/18
# 2023                               NaN                 5/18       NaN    NaN      1    NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  13/18
# ----------------------------------------------- #
# Crop type: Pigeon Peas
# ----------------------------------------------- #
# season_name                 Main
# crop_production_system irrigated
# fnid_short                2013A1
# year
# 2016                        4/18
# ----------------------------------------------- #
# Crop type: Pigeon pea (Unspecified)
# ----------------------------------------------- #
# season_name                Main
# crop_production_system All (PS)
# fnid_short               2005R2 2013A1
# year
# 2016                          3   8/18
# 2017                          2   4/18
# 2018                          2   4/18
# ----------------------------------------------- #
# Crop type: Sesame Seed
# ----------------------------------------------- #
# season_name                 Main
# crop_production_system irrigated               mechanized_rainfed                                           traditional_rainfed
# fnid_short                1990R1 1990R2 2005A1             1990A1 1990R1 1990R2 2005A1 2011A1 2012A1 2013A1              1990A1 1990R2 2005A1 2005R2 2011A1 2012A1 2013A1
# year
# 1990                         NaN    NaN    NaN               5/26    NaN      1    NaN    NaN    NaN    NaN                9/26    NaN    NaN    NaN    NaN    NaN    NaN
# 1991                         NaN    NaN    NaN               6/26    NaN      1    NaN    NaN    NaN    NaN                9/26    NaN    NaN    NaN    NaN    NaN    NaN
# 1992                         NaN    NaN    NaN               6/26      1    NaN    NaN    NaN    NaN    NaN                9/26    NaN    NaN    NaN    NaN    NaN    NaN
# 1993                         NaN    NaN    NaN               5/26      1    NaN    NaN    NaN    NaN    NaN                9/26    NaN    NaN    NaN    NaN    NaN    NaN
# 1994                         NaN    NaN    NaN               5/26      1      1    NaN    NaN    NaN    NaN                8/26    NaN    NaN    NaN    NaN    NaN    NaN
# 1995                         NaN    NaN    NaN               6/26      1      1    NaN    NaN    NaN    NaN                9/26    NaN    NaN    NaN    NaN    NaN    NaN
# 1996                         NaN    NaN    NaN               5/26      1      1    NaN    NaN    NaN    NaN                9/26    NaN    NaN    NaN    NaN    NaN    NaN
# 1997                         NaN    NaN    NaN               6/26      1      1    NaN    NaN    NaN    NaN                9/26    NaN    NaN    NaN    NaN    NaN    NaN
# 1998                         NaN    NaN    NaN               6/26      1      1    NaN    NaN    NaN    NaN                9/26    NaN    NaN    NaN    NaN    NaN    NaN
# 1999                         NaN    NaN    NaN               6/26      1      1    NaN    NaN    NaN    NaN                9/26    NaN    NaN    NaN    NaN    NaN    NaN
# 2000                         NaN    NaN    NaN               6/26      1      1    NaN    NaN    NaN    NaN                9/26    NaN    NaN    NaN    NaN    NaN    NaN
# 2001                         NaN    NaN    NaN               6/26      1      1    NaN    NaN    NaN    NaN                9/26    NaN    NaN    NaN    NaN    NaN    NaN
# 2002                         NaN    NaN    NaN               5/26      1    NaN    NaN    NaN    NaN    NaN                8/26    NaN    NaN    NaN    NaN    NaN    NaN
# 2003                         NaN    NaN    NaN               7/26      1    NaN    NaN    NaN    NaN    NaN                9/26    NaN    NaN    NaN    NaN    NaN    NaN
# 2004                         NaN    NaN    NaN               6/26      1      1    NaN    NaN    NaN    NaN                9/26      1    NaN    NaN    NaN    NaN    NaN
# 2005                         NaN    NaN    NaN                NaN      1    NaN   5/25    NaN    NaN    NaN                 NaN    NaN   8/25    NaN    NaN    NaN    NaN
# 2006                         NaN    NaN    NaN                NaN      1      1   6/25    NaN    NaN    NaN                 NaN    NaN   8/25    NaN    NaN    NaN    NaN
# 2007                         NaN    NaN    NaN                NaN      1      1   6/25    NaN    NaN    NaN                 NaN    NaN   8/25      1    NaN    NaN    NaN
# 2008                           1      1   6/25                NaN    NaN    NaN    NaN    NaN    NaN    NaN                 NaN    NaN   8/25      1    NaN    NaN    NaN
# 2009                         NaN      1   6/25                NaN    NaN    NaN    NaN    NaN    NaN    NaN                 NaN    NaN   9/25      1    NaN    NaN    NaN
# 2010                         NaN    NaN   6/25                NaN    NaN    NaN    NaN    NaN    NaN    NaN                 NaN    NaN   8/25      1    NaN    NaN    NaN
# 2011                         NaN    NaN    NaN                NaN    NaN    NaN    NaN   6/25    NaN    NaN                 NaN    NaN    NaN      1   8/25    NaN    NaN
# 2012                         NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN   6/17    NaN                 NaN    NaN    NaN      1    NaN  10/17    NaN
# 2013                         NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN    NaN   6/18                 NaN    NaN    NaN      1    NaN    NaN  11/18
# 2014                         NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN    NaN   6/18                 NaN    NaN    NaN      1    NaN    NaN  10/18
# 2015                         NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN    NaN   6/18                 NaN    NaN    NaN    NaN    NaN    NaN  11/18
# 2016                         NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN    NaN   6/18                 NaN    NaN    NaN    NaN    NaN    NaN  11/18
# 2017                         NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN    NaN   6/18                 NaN    NaN    NaN    NaN    NaN    NaN  11/18
# 2018                         NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN    NaN   6/18                 NaN    NaN    NaN    NaN    NaN    NaN   9/18
# 2019                         NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN    NaN   6/18                 NaN    NaN    NaN    NaN    NaN    NaN  11/18
# 2020                         NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN    NaN    NaN                 NaN    NaN    NaN    NaN    NaN    NaN  12/18
# 2021                         NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN    NaN   7/18                 NaN    NaN    NaN    NaN    NaN    NaN  13/18
# 2022                         NaN    NaN    NaN                NaN    NaN    NaN    NaN    NaN    NaN   6/18                 NaN    NaN    NaN    NaN    NaN    NaN  13/18
# ----------------------------------------------- #
# Crop type: Sorghum
# ----------------------------------------------- #
# season_name               Annual                                                             Main
# crop_production_system irrigated                                                  Mechanized (PS)        Semi-Mechanized (PS) mechanized_rainfed                                    traditional_rainfed
# fnid_short                1976A1 1990A1 1990R2 2005A1 2005R2 2011A1 2012A1 2013A1          2005R2 2013A1               2013A1             1976A1 1990A1 2005A1 2011A1 2012A1 2013A1              1976A1 1990A1 1990R1 2005A1 2011A1 2012A1 2013A1
# year
# 1975                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                7/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1976                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                7/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1977                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                7/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1978                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                7/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1979                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               1/18    NaN    NaN    NaN    NaN    NaN                7/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1980                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                7/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1981                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                7/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1982                         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                7/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1983                        2/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                7/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1984                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                7/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1985                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                7/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1986                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                4/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1987                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                4/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1988                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                4/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1989                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                  NaN               2/18    NaN    NaN    NaN    NaN    NaN                4/18    NaN    NaN    NaN    NaN    NaN    NaN
# 1990                         NaN   3/26      3    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   7/26    NaN    NaN    NaN    NaN                 NaN  10/26      1    NaN    NaN    NaN    NaN
# 1991                         NaN   3/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   8/26    NaN    NaN    NaN    NaN                 NaN  10/26      1    NaN    NaN    NaN    NaN
# 1992                         NaN   4/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   8/26    NaN    NaN    NaN    NaN                 NaN  11/26      1    NaN    NaN    NaN    NaN
# 1993                         NaN   4/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   8/26    NaN    NaN    NaN    NaN                 NaN  11/26      1    NaN    NaN    NaN    NaN
# 1994                         NaN   4/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   8/26    NaN    NaN    NaN    NaN                 NaN  12/26      1    NaN    NaN    NaN    NaN
# 1995                         NaN   4/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   8/26    NaN    NaN    NaN    NaN                 NaN  12/26      1    NaN    NaN    NaN    NaN
# 1996                         NaN   4/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   8/26    NaN    NaN    NaN    NaN                 NaN  12/26      1    NaN    NaN    NaN    NaN
# 1997                         NaN   4/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   8/26    NaN    NaN    NaN    NaN                 NaN  13/26      1    NaN    NaN    NaN    NaN
# 1998                         NaN   4/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   8/26    NaN    NaN    NaN    NaN                 NaN  13/26      1    NaN    NaN    NaN    NaN
# 1999                         NaN   3/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   8/26    NaN    NaN    NaN    NaN                 NaN  13/26      1    NaN    NaN    NaN    NaN
# 2000                         NaN   4/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   8/26    NaN    NaN    NaN    NaN                 NaN  12/26      1    NaN    NaN    NaN    NaN
# 2001                         NaN   4/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   9/26    NaN    NaN    NaN    NaN                 NaN  13/26      1    NaN    NaN    NaN    NaN
# 2002                         NaN   4/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   8/26    NaN    NaN    NaN    NaN                 NaN  14/26      1    NaN    NaN    NaN    NaN
# 2003                         NaN   4/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   9/26    NaN    NaN    NaN    NaN                 NaN  14/26      1    NaN    NaN    NaN    NaN
# 2004                         NaN   5/26      4    NaN      1    NaN    NaN    NaN             NaN    NaN                  NaN                NaN   9/26    NaN    NaN    NaN    NaN                 NaN  14/26      1    NaN    NaN    NaN    NaN
# 2005                         NaN    NaN    NaN   5/25      5    NaN    NaN    NaN             NaN    NaN                  NaN                NaN    NaN   8/25    NaN    NaN    NaN                 NaN    NaN      1  13/25    NaN    NaN    NaN
# 2006                         NaN    NaN    NaN   4/25      5    NaN    NaN    NaN             NaN    NaN                  NaN                NaN    NaN   8/25    NaN    NaN    NaN                 NaN    NaN      1  14/25    NaN    NaN    NaN
# 2007                         NaN    NaN    NaN   5/25      5    NaN    NaN    NaN             NaN    NaN                  NaN                NaN    NaN   8/25    NaN    NaN    NaN                 NaN    NaN      1  14/25    NaN    NaN    NaN
# 2008                         NaN    NaN    NaN   5/25      5    NaN    NaN    NaN             NaN    NaN                  NaN                NaN    NaN   8/25    NaN    NaN    NaN                 NaN    NaN      1  14/25    NaN    NaN    NaN
# 2009                         NaN    NaN    NaN   5/25      5    NaN    NaN    NaN             NaN    NaN                  NaN                NaN    NaN   7/25    NaN    NaN    NaN                 NaN    NaN      1  13/25    NaN    NaN    NaN
# 2010                         NaN    NaN    NaN   4/25      5    NaN    NaN    NaN             NaN    NaN                  NaN                NaN    NaN   7/25    NaN    NaN    NaN                 NaN    NaN    NaN  13/25    NaN    NaN    NaN
# 2011                         NaN    NaN    NaN    NaN      5   4/25    NaN    NaN             NaN    NaN                  NaN                NaN    NaN    NaN   7/25    NaN    NaN                 NaN    NaN    NaN    NaN  12/25    NaN    NaN
# 2012                         NaN    NaN    NaN    NaN      5    NaN   4/17    NaN             NaN    NaN                  NaN                NaN    NaN    NaN    NaN   7/17    NaN                 NaN    NaN    NaN    NaN    NaN  15/17    NaN
# ...
# 2020                         NaN    NaN    NaN    NaN      5    NaN    NaN   7/18             NaN    NaN                 8/18                NaN    NaN    NaN    NaN    NaN   8/18                 NaN    NaN    NaN    NaN    NaN    NaN  16/18
# 2021                         NaN    NaN    NaN    NaN      5    NaN    NaN   7/18             NaN    NaN                 8/18                NaN    NaN    NaN    NaN    NaN   8/18                 NaN    NaN    NaN    NaN    NaN    NaN  16/18
# 2022                         NaN    NaN    NaN    NaN      5    NaN    NaN   7/18             NaN    NaN                 8/18                NaN    NaN    NaN    NaN    NaN    NaN                 NaN    NaN    NaN    NaN    NaN    NaN  16/18
# 2023                         NaN    NaN    NaN    NaN      4    NaN    NaN   6/18             NaN    NaN                 6/18                NaN    NaN    NaN    NaN    NaN    NaN                 NaN    NaN    NaN    NaN    NaN    NaN  16/18
# ----------------------------------------------- #
# Crop type: Sugarcane (for sugar)
# ----------------------------------------------- #
# season_name              Annual
# crop_production_system All (PS)
# fnid_short               2005R2
# year
# 2015                          3
# 2016                          3
# 2017                          3
# 2018                          3
# 2019                          2
# 2020                          3
# 2021                          3
# 2022                          1
# ----------------------------------------------- #
# Crop type: Sunflower Seed
# ----------------------------------------------- #
# season_name                    Main
# crop_production_system Rainfed (PS) irrigated                                           mechanized_rainfed traditional_rainfed
# fnid_short                   2013A1    1990A1 1990R2 2005A1 2005R2 2011A1 2012A1 2013A1             2013A1              1990A1 1990R2 2005A1 2011A1 2012A1 2013A1
# year
# 1990                            NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN                NaN                3/26      1    NaN    NaN    NaN    NaN
# 1991                            NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN                NaN                2/26      1    NaN    NaN    NaN    NaN
# 1992                            NaN      1/26    NaN    NaN    NaN    NaN    NaN    NaN                NaN                2/26      1    NaN    NaN    NaN    NaN
# 1993                            NaN      1/26      1    NaN    NaN    NaN    NaN    NaN                NaN                3/26      1    NaN    NaN    NaN    NaN
# 1994                            NaN      2/26      2    NaN    NaN    NaN    NaN    NaN                NaN                3/26      1    NaN    NaN    NaN    NaN
# 1995                            NaN      2/26      2    NaN    NaN    NaN    NaN    NaN                NaN                4/26      1    NaN    NaN    NaN    NaN
# 1996                            NaN      1/26      1    NaN    NaN    NaN    NaN    NaN                NaN                3/26    NaN    NaN    NaN    NaN    NaN
# 1997                            NaN      1/26      2    NaN    NaN    NaN    NaN    NaN                NaN                2/26      1    NaN    NaN    NaN    NaN
# 1998                            NaN       NaN      2    NaN    NaN    NaN    NaN    NaN                NaN                3/26      1    NaN    NaN    NaN    NaN
# 1999                            NaN       NaN      1    NaN    NaN    NaN    NaN    NaN                NaN                3/26      1    NaN    NaN    NaN    NaN
# 2000                            NaN      1/26    NaN    NaN    NaN    NaN    NaN    NaN                NaN                3/26      1    NaN    NaN    NaN    NaN
# 2001                            NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN                NaN                3/26    NaN    NaN    NaN    NaN    NaN
# 2002                            NaN       NaN      1    NaN    NaN    NaN    NaN    NaN                NaN                2/26    NaN    NaN    NaN    NaN    NaN
# 2003                            NaN       NaN      2    NaN    NaN    NaN    NaN    NaN                NaN                3/26    NaN    NaN    NaN    NaN    NaN
# 2004                            NaN      1/26      1    NaN    NaN    NaN    NaN    NaN                NaN                2/26    NaN    NaN    NaN    NaN    NaN
# 2005                            NaN       NaN    NaN   2/25      2    NaN    NaN    NaN                NaN                 NaN      1   3/25    NaN    NaN    NaN
# 2006                            NaN       NaN    NaN   2/25      2    NaN    NaN    NaN                NaN                 NaN      1   4/25    NaN    NaN    NaN
# 2007                            NaN       NaN    NaN   1/25      2    NaN    NaN    NaN                NaN                 NaN      1   5/25    NaN    NaN    NaN
# 2008                            NaN       NaN    NaN   1/25      3    NaN    NaN    NaN                NaN                 NaN      1   5/25    NaN    NaN    NaN
# 2009                            NaN       NaN    NaN   1/25      2    NaN    NaN    NaN                NaN                 NaN    NaN   4/25    NaN    NaN    NaN
# 2010                            NaN       NaN    NaN    NaN      3    NaN    NaN    NaN                NaN                 NaN    NaN   3/25    NaN    NaN    NaN
# 2011                            NaN       NaN    NaN    NaN      3   1/25    NaN    NaN                NaN                 NaN    NaN    NaN   4/25    NaN    NaN
# 2012                            NaN       NaN    NaN    NaN      3    NaN   1/17    NaN                NaN                 NaN    NaN    NaN    NaN   3/17    NaN
# 2013                            NaN       NaN    NaN    NaN      3    NaN    NaN    NaN                NaN                 NaN    NaN    NaN    NaN    NaN   3/18
# 2014                            NaN       NaN    NaN    NaN      3    NaN    NaN    NaN                NaN                 NaN    NaN    NaN    NaN    NaN   3/18
# 2015                            NaN       NaN    NaN    NaN    NaN    NaN    NaN   3/18               2/18                 NaN    NaN    NaN    NaN    NaN   2/18
# 2016                           3/18       NaN    NaN    NaN      1    NaN    NaN   1/18               4/18                 NaN    NaN    NaN    NaN    NaN    NaN
# 2017                           3/18       NaN    NaN    NaN      3    NaN    NaN    NaN                NaN                 NaN    NaN    NaN    NaN    NaN    NaN
# 2018                           3/18       NaN    NaN    NaN      3    NaN    NaN   1/18                NaN                 NaN    NaN    NaN    NaN    NaN    NaN
# 2019                           3/18       NaN    NaN    NaN      1    NaN    NaN   1/18                NaN                 NaN    NaN    NaN    NaN    NaN    NaN
# 2020                            NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN                NaN                 NaN    NaN    NaN    NaN    NaN   3/18
# 2021                           4/18       NaN    NaN    NaN      2    NaN    NaN    NaN                NaN                 NaN    NaN    NaN    NaN    NaN   4/18
# 2022                           4/18       NaN    NaN    NaN      2    NaN    NaN    NaN                NaN                 NaN    NaN    NaN    NaN    NaN    NaN
# ----------------------------------------------- #
# Crop type: Wheat Grain
# ----------------------------------------------- #
# season_name               Annual                                                             Main
# crop_production_system irrigated                                                  Mechanized (PS)        traditional_rainfed
# fnid_short                1976A1 1990A1 1990R2 2005A1 2005R2 2011A1 2012A1 2013A1          2005R2 2013A1              1990A1 2005A1 2011A1 2012A1 2013A1
# year
# 1975                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1976                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1977                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1978                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1979                        2/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1980                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1981                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1982                         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1983                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1984                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1985                        2/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1986                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1987                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1988                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1989                        3/18    NaN    NaN    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1990                         NaN   5/26      4    NaN    NaN    NaN    NaN    NaN             NaN    NaN                1/26    NaN    NaN    NaN    NaN
# 1991                         NaN   5/26      3    NaN    NaN    NaN    NaN    NaN             NaN    NaN                1/26    NaN    NaN    NaN    NaN
# 1992                         NaN   5/26      3    NaN    NaN    NaN    NaN    NaN             NaN    NaN                1/26    NaN    NaN    NaN    NaN
# 1993                         NaN   5/26      3    NaN    NaN    NaN    NaN    NaN             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 1994                         NaN   4/26      3    NaN    NaN    NaN    NaN    NaN             NaN    NaN                1/26    NaN    NaN    NaN    NaN
# 1995                         NaN   3/26      3    NaN    NaN    NaN    NaN    NaN             NaN    NaN                1/26    NaN    NaN    NaN    NaN
# 1996                         NaN   4/26      3    NaN    NaN    NaN    NaN    NaN             NaN    NaN                2/26    NaN    NaN    NaN    NaN
# 1997                         NaN   4/26      4    NaN    NaN    NaN    NaN    NaN             NaN    NaN                2/26    NaN    NaN    NaN    NaN
# 1998                         NaN   3/26      3    NaN    NaN    NaN    NaN    NaN             NaN    NaN                1/26    NaN    NaN    NaN    NaN
# 1999                         NaN   3/26      2    NaN    NaN    NaN    NaN    NaN             NaN    NaN                1/26    NaN    NaN    NaN    NaN
# 2000                         NaN   3/26      2    NaN    NaN    NaN    NaN    NaN             NaN    NaN                1/26    NaN    NaN    NaN    NaN
# 2001                         NaN   3/26      2    NaN    NaN    NaN    NaN    NaN             NaN    NaN                1/26    NaN    NaN    NaN    NaN
# 2002                         NaN   3/26      2    NaN    NaN    NaN    NaN    NaN             NaN    NaN                1/26    NaN    NaN    NaN    NaN
# 2003                         NaN   3/26      2    NaN    NaN    NaN    NaN    NaN             NaN    NaN                1/26    NaN    NaN    NaN    NaN
# 2004                         NaN   3/26      2    NaN    NaN    NaN    NaN    NaN             NaN    NaN                1/26    NaN    NaN    NaN    NaN
# 2005                         NaN    NaN    NaN   3/25      2    NaN    NaN    NaN             NaN    NaN                 NaN   2/25    NaN    NaN    NaN
# 2006                         NaN    NaN    NaN   3/25      2    NaN    NaN    NaN             NaN    NaN                 NaN   2/25    NaN    NaN    NaN
# 2007                         NaN    NaN    NaN   3/25      5    NaN    NaN    NaN             NaN    NaN                 NaN   2/25    NaN    NaN    NaN
# 2008                         NaN    NaN    NaN   3/25      4    NaN    NaN    NaN             NaN    NaN                 NaN   2/25    NaN    NaN    NaN
# 2009                         NaN    NaN    NaN   3/25      3    NaN    NaN    NaN             NaN    NaN                 NaN   2/25    NaN    NaN    NaN
# 2010                         NaN    NaN    NaN   3/25      4    NaN    NaN    NaN             NaN    NaN                 NaN   2/25    NaN    NaN    NaN
# 2011                         NaN    NaN    NaN    NaN      3   3/25    NaN    NaN             NaN    NaN                 NaN    NaN   2/25    NaN    NaN
# 2012                         NaN    NaN    NaN    NaN      2    NaN   3/17    NaN             NaN    NaN                 NaN    NaN    NaN   2/17    NaN
# 2013                         NaN    NaN    NaN    NaN      3    NaN    NaN   3/18             NaN    NaN                 NaN    NaN    NaN    NaN   2/18
# 2014                         NaN    NaN    NaN    NaN      3    NaN    NaN   3/18             NaN    NaN                 NaN    NaN    NaN    NaN   2/18
# 2015                         NaN    NaN    NaN    NaN      1    NaN    NaN   5/18             NaN    NaN                 NaN    NaN    NaN    NaN   3/18
# 2016                         NaN    NaN    NaN    NaN      2    NaN    NaN   4/18               2   5/18                 NaN    NaN    NaN    NaN   3/18
# 2017                         NaN    NaN    NaN    NaN      1    NaN    NaN   4/18               1   4/18                 NaN    NaN    NaN    NaN   1/18
# 2018                         NaN    NaN    NaN    NaN      1    NaN    NaN   5/18             NaN    NaN                 NaN    NaN    NaN    NaN   2/18
# 2019                         NaN    NaN    NaN    NaN      2    NaN    NaN   5/18             NaN    NaN                 NaN    NaN    NaN    NaN   2/18
# 2020                         NaN    NaN    NaN    NaN      2    NaN    NaN   6/18             NaN    NaN                 NaN    NaN    NaN    NaN   2/18
# 2021                         NaN    NaN    NaN    NaN      2    NaN    NaN   4/18             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 2022                         NaN    NaN    NaN    NaN      1    NaN    NaN   5/18             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# 2023                         NaN    NaN    NaN    NaN      1    NaN    NaN   4/18             NaN    NaN                 NaN    NaN    NaN    NaN    NaN
# ----------------------------------------------- #
# ../figures/SD_admin_shapes.png is saved.

# %% [markdown]
# ## Sudan and South Sudan
# Sudan and South Sudan crop seasonal calendar
#
# <img src="https://fews.net/sites/default/files/styles/large_width_880/public/2023-03/seasonal-calendar-sudan.png?itok=DRc-ECNF" width=900></br>
#
# <img src="https://ipad.fas.usda.gov/countrysummary/images/SU/cropcalendar/eafrica_su_calendar.png" width=900>
#
# - comparison of boundaries
#
# <img src="../figures/SD_admin_shapes.png" width=900>
#
# - In Sudan and South Sudan, basd on the FEWS NET data, there were six changes in administrative units, although they are mostly minor at the admin 1 level
#
# | year	 | Admin1   | # units   | Admin2   | # units   |
# | :---: | :----:  | :----:   | :----:   | :---:  |
# | 1976	 | SD1976A1 | 18	| nan	| 0	|
# | 1990	 | SD1990A1 | 26	| nan	| 0	|
# | 2005	 | SD2005A1 | 25	| nan	| 0	|
# | 2011	 | SD2011A1 | 15	| SD2011A2	| 133	|
# | 2012	 | SD2012A1 | 17	| nan	| 0	|
# | 2013	 | SD2013A1 | 18	| nan	| 0	|
#
#
# - Only wheat has two seasons (Main and Winter), and the vast majority of data is winter
# - While there is a shapefile for 2014 and 2021, there is no crop data associated with either shapefile, so we use 2013 as the most recent shapefile

# %%
# Define the latest shapefile ------------------- #
latest_level = 1
shape_latest = SD_Admin1_2013.copy().to_crs('epsg:20135')
# ----------------------------------------------- #

# Validation of FNIDs and Names ----------------- #
df = FDW_PD_ValidateFnidName(df, shape_used, shape_latest)
# ----------------------------------------------- #

# FDW Production Data Compiling ----------------- #
area, prod = FDW_PD_Compiling(df, shape_used)
area_all, prod_all = area.copy(), prod.copy()
mdx_pss = area.columns.droplevel([0,1]).unique()
# ----------------------------------------------- #
# Out:
# SD2011A115:	"Gezira" (FDW) is changed to "Jazirah" (shapefile).
# SD2011A112:	"Gedaref" (FDW) is changed to "Qadarif" (shapefile).

# %%
# Link admin boundaries ------------------------- #
link_1976, over_1976 = FDW_PD_CreateAdminLink(SD_Admin1_1976, SD_Admin1_2013, 'ADMIN1', 'ADMIN1', prod, epsg)
link_1990, over_1990 = FDW_PD_CreateAdminLink(SD_Admin1_1990, SD_Admin1_2013, 'ADMIN1', 'ADMIN1', prod, epsg)
link_2005, over_2005 = FDW_PD_CreateAdminLink(SD_Admin1_2005, SD_Admin1_2013, 'ADMIN1', 'ADMIN1', prod, epsg)
link_2011, over_2011 = FDW_PD_CreateAdminLink(SD_Admin1_2011, SD_Admin1_2013, 'ADMIN1', 'ADMIN1', prod, epsg)
link_2012, over_2012 = FDW_PD_CreateAdminLink(SD_Admin1_2012, SD_Admin1_2013, 'ADMIN1', 'ADMIN1', prod, epsg)


# Crop specific ratios
link_ratio_1976 = FDW_PD_RatioAdminLink(link_1976, prod, over_1976, mdx_pss)
link_ratio_1990 = FDW_PD_RatioAdminLink(link_1990, prod, over_1990, mdx_pss)
link_ratio_2005 = FDW_PD_RatioAdminLink(link_2005, prod, over_2005, mdx_pss)
link_ratio_2011 = FDW_PD_RatioAdminLink(link_2011, prod, over_2011, mdx_pss)
link_ratio_2012 = FDW_PD_RatioAdminLink(link_2012, prod, over_2012, mdx_pss)


# Merge link_ratio
assert link_ratio_1976.keys() == link_ratio_2012.keys()
assert link_ratio_1990.keys() == link_ratio_2012.keys()
assert link_ratio_2005.keys() == link_ratio_2012.keys()
assert link_ratio_2011.keys() == link_ratio_2012.keys()

link_merged = [link_ratio_1976, link_ratio_1990, link_ratio_2005, 
               link_ratio_2011, link_ratio_2012]
fnids_new = list(link_merged[0].keys())
link_ratio = dict()
for fnid in fnids_new:
    container = []
    for link in link_merged:
        container.append(link[fnid])
    link_ratio[fnid] = pd.concat(container, axis=1)
# Add current unit to link_ratio
for fnid_new in link_ratio.keys():
    link_ratio[fnid_new][fnid_new] = 1.0
    link_ratio[fnid_new] = link_ratio[fnid_new].sort_index(axis=1, ascending=False)
# Connect data with AdminLink
area_new, prod_new = FDW_PD_ConnectAdminLink(link_ratio, area, prod, validation=False)
# ----------------------------------------------- #

# %%
# Manual correction ----------------------------- #
crop_new = prod_new/area_new

# Complete long format DataFrame ---------------- #
df_area = area_new.T.stack().rename('value').reset_index()
df_area['indicator'] = 'area'
df_prod = prod_new.T.stack().rename('value').reset_index()
df_prod['indicator'] = 'production'
df_yield = (prod_new/area_new).T.stack().rename('value').reset_index()
df_yield['indicator'] = 'yield'
stack = pd.concat([df_area, df_prod, df_yield], axis=0)
# Add "growing year"
cols = ['season_name','product','crop_production_system','planting_month','harvest_year','harvest_month','planting_year']
season_table = df[cols].drop_duplicates()
stack = stack.merge(season_table, on=cols[:-1])
#stack = stack.merge(df[['fnid','country','country_code','admin_1','admin_2']].drop_duplicates(), on='fnid', how='inner')

# %%
# Manual correction ----------------------------- #
crop_new = prod_new/area_new

# Complete long format DataFrame ---------------- #
df_area = area_new.T.stack().rename('value').reset_index()
df_area['indicator'] = 'area'
df_prod = prod_new.T.stack().rename('value').reset_index()
df_prod['indicator'] = 'production'
df_yield = (prod_new/area_new).T.stack().rename('value').reset_index()
df_yield['indicator'] = 'yield'
stack = pd.concat([df_area, df_prod, df_yield], axis=0)
# Add "planting year"
cols = ['season_name','product','crop_production_system','planting_month','harvest_year','harvest_month','planting_year']
season_table = df[cols].drop_duplicates()
stack = stack.merge(season_table, on=cols[:-1])
# Add country and admin names
stack = stack.merge(df[['fnid','country','country_code','admin_1','admin_2']].drop_duplicates(), on='fnid', how='inner')
names = [
    'fnid','country','country_code','admin_1','admin_2','name',
    'product','season_name','planting_year','planting_month','harvest_year','harvest_month',
    'crop_production_system','indicator','value'
]
stack = stack[names]

# Final Processing ------------------------------ #
# Product name mapping
stack = product_name_mapping(stack, list_except=None)
# Calibration of crop calendar using External Season Calendar (ESC)
# esc = pd.read_csv('../data/crop_calendar/external_crop_calendar.csv')
# stack, link_ratio = FDW_PD_CaliSeasonYear(stack, esc, link_ratio=None)
# None admin names
stack.loc[stack['admin_1'].isna(), 'admin_1'] = 'none'
stack.loc[stack['admin_2'].isna(), 'admin_2'] = 'none'
# ----------------------------------------------- #

#define a QC flag field
# 0 = no flag
# 1 = outlier
stack['QC_flag'] = 0

# Save data
stack_sd = stack[stack['country'] == 'Sudan'].reset_index(drop=True)
fn_out = '../data/crop/adm_crop_production_SD.csv'
stack_sd.to_csv(fn_out); print(f'{fn_out} is saved.')
stack_ss = stack[stack['country'] == 'South Sudan'].reset_index(drop=True)
fn_out = '../data/crop/adm_crop_production_SS.csv'
stack_ss.to_csv(fn_out); print(f'{fn_out} is saved.')
# Out:
# ../data/crop/adm_crop_production_SD.csv is saved.
# ../data/crop/adm_crop_production_SS.csv is saved.

# %% [markdown]
# # Visualization of production data

# %%
# Bar chart of national crop production
country_iso, country_name = 'SD', 'Sudan'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso, index_col=0)
df = df[df['QC_flag'] == 0] # remove outliers
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
for season_name in ['Main','Annual']:
    footnote = 'National crop production of %s - %s' % (country_name, season_name)
    fn_save = '../figures/%s_bar_natgrainprod_%s.png' % (country_iso, season_name)
    sub = df[df['season_name'] == season_name]
    PlotBarProduction(sub, year, footnote, fn_save)
# Out:
# E:\upload _gscd\gscd\notebook\tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/SD_bar_natgrainprod_Main.png is saved.
# E:\upload _gscd\gscd\notebook\tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/SD_bar_natgrainprod_Annual.png is saved.

# %%
# Lineplot of Production-Area-Yield time-series
country_iso, country_name ='SD', 'Sudan'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso, index_col=0)
df = df[df['QC_flag'] == 0] # remove outliers
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
product_season = [
    ['Millet','Main'],
    ['Sorghum','Main'],
    ['Wheat','Winter'],
]
for product_name, season_name in product_season:
    footnote = 'Time-series of %s - %s - %s' % (country_iso, product_name, season_name)
    fn_save = '../figures/%s_line_pay_%s_%s.png' % (country_iso, product_name, season_name)
    sub = df[(df['product'] == product_name) & (df['season_name'] == season_name)]
    PlotLinePAY(sub, year, footnote)
# Out:
# No data to plot for Time-series of SD - Wheat - Winter.

# %%
# Bar chart of national crop production
country_iso, country_name = 'SS', 'South Sudan'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso, index_col=0)
df = df[df['QC_flag'] == 0] # remove outliers
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
for season_name in ['Main']:
    footnote = 'National crop production of %s - %s' % (country_name, season_name)
    fn_save = '../figures/%s_bar_natgrainprod_%s.png' % (country_iso, season_name)
    sub = df[df['season_name'] == season_name]
    PlotBarProduction(sub, year, footnote, fn_save)
# Out:
# E:\upload _gscd\gscd\notebook\tools_graphic.py:135: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   axes[1].grid(which='minor', axis='x', linestyle='-', color='black', visible=False)
# ../figures/SS_bar_natgrainprod_Main.png is saved.

# %%
# Lineplot of Production-Area-Yield time-series
country_iso, country_name = 'SS', 'South Sudan'
df = pd.read_csv('../data/crop/adm_crop_production_%s.csv' % country_iso, index_col=0)
df = df[df['QC_flag'] == 0] # remove outliers
df['year'] = df['harvest_year']
year = [df['year'].min(), df['year'].max()]
product_season = [
    ['Cereal Crops','Main']
]
for product_name, season_name in product_season:
    footnote = 'Time-series of %s - %s - %s' % (country_iso, product_name, season_name)
    fn_save = '../figures/%s_line_pay_%s_%s.png' % (country_iso, product_name, season_name)
    sub = df[(df['product'] == product_name) & (df['season_name'] == season_name)]
    PlotLinePAY(sub, year, footnote)
